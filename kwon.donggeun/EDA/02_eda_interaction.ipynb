# %% [markdown]
# # 교호작용 EDA: 100원딜 × 다른 변수 → 재구매 / 이탈방지
#
# `is_100` (100원 프로모션 여부) 와 다른 변수들의 **교호작용(interaction)** 이
# `is_repurchase`, `is_churn_prevented` 에 미치는 영향을 분석합니다.
#
# | 분석 | 설명 |
# |------|------|
# | is_100 × gender | 성별에 따라 100원딜 효과가 다른가? |
# | is_100 × age_group | 연령대별 100원딜 효과 차이 |
# | is_100 × payment_device | 결제 기기별 100원딜 효과 |
# | is_100 × max_screen | 동시접속 화면 수 × 100원딜 |
# | is_100 × billing_method | 결제 방식 × 100원딜 |
# | is_100 × reg_hour_group | 가입 시간대 × 100원딜 |
# | is_100 × is_promotion | 프로모션 × 100원딜 |
# | is_100 × product_code | 상품별 100원딜 효과 차이 |
# | is_100 × is_user_verified | 본인인증 여부별 100원딜 효과 |
# | is_100 × reg_month | 월별 가입 추이 × 100원딜 |

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False
sns.set_palette('Set2')

df = pd.read_csv('../../_data/02_interim/260430_membership_v1(이상치, 이름변경)/Membership_v1.csv', encoding='utf-8-sig')

df['is_100'] = (df['price'] == 100).astype(int)
df['price_label'] = df['is_100'].map({1: '100원', 0: '일반요금'})
df['age_group'] = pd.cut(df['age'], bins=[14, 19, 29, 39, 49, 70],
                         labels=['10대', '20대', '30대', '40대', '50대+'])
df['reg_hour_group'] = pd.cut(df['reg_hour'], bins=[-1, 5, 11, 17, 23],
                               labels=['새벽(0-5)', '오전(6-11)', '오후(12-17)', '저녁(18-23)'])

OUTCOMES = ['is_repurchase', 'is_churn_prevented']
OUTCOME_LABELS = {'is_repurchase': '재구매율(%)', 'is_churn_prevented': '이탈방지율(%)'}

_N_TOTAL = len(df)
_N_100   = int(df['is_100'].sum())
_N_ETC   = int((df['is_100'] == 0).sum())
_N_INFO  = (f'전체 N={_N_TOTAL:,}명  |  '
            f'100원: {_N_100:,}명 ({_N_100/_N_TOTAL*100:.1f}%)  |  '
            f'일반요금: {_N_ETC:,}명 ({_N_ETC/_N_TOTAL*100:.1f}%)')

def interaction_barplot(df, group_col, group_label, figsize=(14, 5)):
    """is_100 × group_col 별 outcome 비율 비교 차트 (바 위에 %와 n 표시)"""
    cnt_pivot = (df.groupby([group_col, 'price_label'])
                   .size()
                   .unstack('price_label')
                   .reindex(columns=['100원', '일반요금']))
    fig, axes = plt.subplots(1, 2, figsize=figsize)
    for ax, outcome in zip(axes, OUTCOMES):
        pivot = df.groupby([group_col, 'price_label'])[outcome].mean().mul(100).unstack('price_label')
        pivot[['100원', '일반요금']].plot(kind='bar', ax=ax,
                                          color=['steelblue', 'salmon'],
                                          width=0.7, edgecolor='white')
        ax.set_title(f'{group_label} × 100원딜 → {OUTCOME_LABELS[outcome]}')
        ax.set_xlabel(group_label)
        ax.set_ylabel('%')
        ax.tick_params(axis='x', rotation=45)
        ax.legend(title='가격 구분')
        n_idx = len(pivot)
        for i, p in enumerate(ax.patches):
            h = p.get_height()
            if not np.isnan(h):
                col_idx = i // n_idx   # 0=100원, 1=일반요금
                row_idx = i % n_idx
                col_name = ['100원', '일반요금'][col_idx]
                row_name = pivot.index[row_idx]
                try:
                    n = int(cnt_pivot.loc[row_name, col_name])
                except (KeyError, TypeError):
                    n = 0
                ax.annotate(f'{h:.1f}%\n(n={n:,})',
                            (p.get_x() + p.get_width()/2, h),
                            ha='center', va='bottom', fontsize=7)
    fig.suptitle(_N_INFO, fontsize=9, y=1.02)
    plt.tight_layout()
    plt.show()

def interaction_heatmap(df, group_col, group_label):
    """교호작용 차이(gap) 히트맵 (셀에 %와 n 표시)"""
    cnt_pivot = df.groupby([group_col, 'price_label']).size().unstack('price_label')
    fig, axes = plt.subplots(1, 2, figsize=(14, 4))
    for ax, outcome in zip(axes, OUTCOMES):
        pivot = df.groupby([group_col, 'price_label'])[outcome].mean().mul(100).unstack('price_label')
        pivot['gap(100원-일반)'] = pivot.get('100원', 0) - pivot.get('일반요금', 0)
        heat = pivot[['100원', '일반요금', 'gap(100원-일반)']].T
        annot = heat.copy().astype(object)
        for r in heat.index:
            for c in heat.columns:
                val = heat.loc[r, c]
                if pd.isna(val):
                    annot.loc[r, c] = ''
                elif r == 'gap(100원-일반)':
                    annot.loc[r, c] = f'{val:.1f}%p'
                else:
                    try:
                        n = int(cnt_pivot.loc[c, r])
                    except (KeyError, TypeError):
                        n = 0
                    annot.loc[r, c] = f'{val:.1f}%\n(n={n:,})'
        sns.heatmap(heat, annot=annot, fmt='', cmap='RdYlGn', ax=ax,
                    linewidths=0.5, cbar_kws={'label': '%'}, annot_kws={'size': 7})
        ax.set_title(f'{group_label} × 100원딜 히트맵 ({OUTCOME_LABELS[outcome]})')
        ax.set_xlabel(group_label)
    fig.suptitle(_N_INFO, fontsize=9, y=1.02)
    plt.tight_layout()
    plt.show()

print('데이터 준비 완료')
print(_N_INFO)
# Out:
# 데이터 준비 완료
# 전체 N=17,876명  |  100원: 9,061명 (50.7%)  |  일반요금: 8,815명 (49.3%)

# %% [markdown]
# ---
# ## 1. is_100 × gender (성별)

# %%
interaction_barplot(df, 'gender', '성별')
interaction_heatmap(df, 'gender', '성별')

print('=== 성별 × 가격구분별 재구매율/이탈방지율 (%) ===')
print(df.groupby(['gender', 'price_label'])[OUTCOMES].mean().mul(100).round(2))
# Out:
# === 성별 × 가격구분별 재구매율/이탈방지율 (%) ===
#                     is_repurchase  is_churn_prevented
# gender price_label
# F      100원                 62.29               16.15
#        일반요금                 70.01               26.13
# M      100원                 63.15               15.23
#        일반요금                 73.36               25.66
# N      100원                100.00                0.00
#        일반요금                 66.84                7.66

# %% [markdown]
# ---
# ## 2. is_100 × age_group (연령대)

# %%
interaction_barplot(df, 'age_group', '연령대', figsize=(16, 5))
interaction_heatmap(df, 'age_group', '연령대')

print('=== 연령대 × 가격구분별 재구매율/이탈방지율 (%) ===')
print(df.groupby(['age_group', 'price_label'])[OUTCOMES].mean().mul(100).round(2))
# Out:
# === 연령대 × 가격구분별 재구매율/이탈방지율 (%) ===
#                        is_repurchase  is_churn_prevented
# age_group price_label
# 10대       100원                 49.36               18.30
#           일반요금                 52.27               45.45
# 20대       100원                 55.84               15.05
#           일반요금                 67.87               29.70
# 30대       100원                 69.76               16.69
#           일반요금                 74.79               28.43
# 40대       100원                 67.47               17.44
#           일반요금                 68.23               12.01
# 50대+      100원                 64.54               13.22
#           일반요금                 77.05               26.75

# %% [markdown]
# ---
# ## 3. is_100 × payment_device (결제 기기)

# %%
interaction_barplot(df, 'payment_device', '결제 기기', figsize=(16, 5))
interaction_heatmap(df, 'payment_device', '결제 기기')

print('=== 결제기기 × 가격구분별 재구매율/이탈방지율 (%) ===')
print(df.groupby(['payment_device', 'price_label'])[OUTCOMES].mean().mul(100).round(2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 interaction_barplot(df, 'payment_device', '결제 기기', figsize=(16, 5))
#       2 interaction_heatmap(df, 'payment_device', '결제 기기')
#       4 print('=== 결제기기 × 가격구분별 재구매율/이탈방지율 (%) ===')
#
# Cell In[12], line 58, in interaction_barplot(df, group_col, group_label, figsize)
#      56 row_name = pivot.index[row_idx]
#      57 try:
# ---> 58     n = int(cnt_pivot.loc[row_name, col_name])
#      59 except (KeyError, TypeError):
#      60     n = 0
#
# ValueError: cannot convert float NaN to integer

# %% [markdown]
# ---
# ## 4. is_100 × max_screen (동시접속 화면 수)

# %%
interaction_barplot(df, 'max_screen', '동시접속 화면 수')
interaction_heatmap(df, 'max_screen', '동시접속 화면 수')

print('=== max_screen × 가격구분별 재구매율/이탈방지율 (%) ===')
print(df.groupby(['max_screen', 'price_label'])[OUTCOMES].mean().mul(100).round(2))
# Out:
# === max_screen × 가격구분별 재구매율/이탈방지율 (%) ===
#                         is_repurchase  is_churn_prevented
# max_screen price_label
# 1          100원                 64.95               15.94
#            일반요금                 67.54               19.25
# 2          100원                 73.83               15.73
#            일반요금                 74.43               22.38
# 4          100원                 48.02               15.45
#            일반요금                 73.37               21.42

# %% [markdown]
# ---
# ## 5. is_100 × billing_method (결제 방식)

# %%
interaction_barplot(df, 'billing_method', '결제 방식', figsize=(18, 5))
interaction_heatmap(df, 'billing_method', '결제 방식')

print('=== billing_method × 가격구분별 재구매율/이탈방지율 (%) ===')
print(df.groupby(['billing_method', 'price_label'])[OUTCOMES].mean().mul(100).round(2))
# Out:
# === billing_method × 가격구분별 재구매율/이탈방지율 (%) ===
#                             is_repurchase  is_churn_prevented
# billing_method price_label
# 121            일반요금                100.00                0.00
# 131            100원                 72.09               14.16
#                일반요금                 76.81               22.73
# 132            100원                 62.27               14.01
#                일반요금                 73.74               27.09
# 134            100원                 63.64               16.02
#                일반요금                 75.35               30.36
# 140            일반요금                 62.88                2.80
# 151            100원                 65.25               18.42
#                일반요금                 72.68               33.56
# 160            일반요금                  0.00                0.00
# 170            100원                 55.81               16.28
#                일반요금                 74.36               29.49
# 180            100원                 56.10               13.93
#                일반요금                 67.99               24.61
# 190            100원                 53.18               14.83
#                일반요금                 65.67               35.82

# %% [markdown]
# ---
# ## 6. is_100 × reg_hour_group (가입 시간대)

# %%
interaction_barplot(df, 'reg_hour_group', '가입 시간대', figsize=(16, 5))
interaction_heatmap(df, 'reg_hour_group', '가입 시간대')

print('=== 가입시간대 × 가격구분별 재구매율/이탈방지율 (%) ===')
print(df.groupby(['reg_hour_group', 'price_label'])[OUTCOMES].mean().mul(100).round(2))
# Out:
# === 가입시간대 × 가격구분별 재구매율/이탈방지율 (%) ===
#                             is_repurchase  is_churn_prevented
# reg_hour_group price_label
# 새벽(0-5)        100원                 59.97               16.59
#                일반요금                 67.20               20.06
# 오전(6-11)       100원                 65.58               17.44
#                일반요금                 72.09               24.29
# 오후(12-17)      100원                 64.37               15.43
#                일반요금                 69.43               18.22
# 저녁(18-23)      100원                 61.72               15.15
#                일반요금                 70.00               18.99

# %% [markdown]
# ---
# ## 7. is_100 × is_promotion (프로모션 여부)

# %%
df['is_promotion_label'] = df['is_promotion'].map({0: '프로모션 아님', 1: '프로모션'})

interaction_barplot(df, 'is_promotion_label', '프로모션 여부')
interaction_heatmap(df, 'is_promotion_label', '프로모션 여부')

print('=== 프로모션여부 × 가격구분별 재구매율/이탈방지율 (%) ===')
print(df.groupby(['is_promotion_label', 'price_label'])[OUTCOMES].mean().mul(100).round(2))
# Out:
# === 프로모션여부 × 가격구분별 재구매율/이탈방지율 (%) ===
#                                 is_repurchase  is_churn_prevented
# is_promotion_label price_label
# 프로모션               100원                 62.63               15.79
# 프로모션 아님            일반요금                 69.84               20.25

# %%
# ═══════════════════════════════════════════════════
# 8. is_100 × product_code (상품 코드)
# ═══════════════════════════════════════════════════
interaction_barplot(df, 'product_code', '상품 코드', figsize=(20, 5))
interaction_heatmap(df, 'product_code', '상품 코드')

print('=== product_code × 가격구분별 재구매율/이탈방지율 (%) ===')
print(df.groupby(['product_code', 'price_label'])[OUTCOMES].mean().mul(100).round(2))

# ═══════════════════════════════════════════════════
# 9. is_100 × is_user_verified (본인인증 여부)
# ═══════════════════════════════════════════════════
df['user_verified_label'] = df['is_user_verified'].map({0: '미인증', 1: '인증'})

interaction_barplot(df, 'user_verified_label', '본인인증 여부')
interaction_heatmap(df, 'user_verified_label', '본인인증 여부')

print('=== 본인인증여부 × 가격구분별 재구매율/이탈방지율 (%) ===')
print(df.groupby(['user_verified_label', 'price_label'])[OUTCOMES].mean().mul(100).round(2))

# ═══════════════════════════════════════════════════
# 10. is_100 × reg_month (가입 월별 추이)
# ═══════════════════════════════════════════════════
df['reg_ym'] = pd.to_datetime(df['reg_date']).dt.to_period('M').astype(str)

fig, axes = plt.subplots(1, 2, figsize=(16, 5))
for ax, outcome in zip(axes, OUTCOMES):
    for label, sub in [('100원', df[df['is_100']==1]), ('일반요금', df[df['is_100']==0])]:
        trend = sub.groupby('reg_ym')[outcome].mean().mul(100)
        ax.plot(trend.index, trend.values, marker='o', label=label)
    ax.set_title(f'월별 가입 × 100원딜 → {OUTCOME_LABELS[outcome]}')
    ax.set_xlabel('가입월')
    ax.set_ylabel('%')
    ax.tick_params(axis='x', rotation=45)
    ax.legend(title='가격 구분')
plt.tight_layout()
plt.show()

print('=== 가입월 × 가격구분별 재구매율/이탈방지율 (%) ===')
print(df.groupby(['reg_ym', 'price_label'])[OUTCOMES].mean().mul(100).round(2))
# Out:
# === product_code × 가격구분별 재구매율/이탈방지율 (%) ===
#                           is_repurchase  is_churn_prevented
# product_code price_label
# pk_1070      일반요금                 66.67               33.33
# pk_1136      일반요금                 51.61                0.00
# pk_1139      일반요금                 42.86                0.00
# pk_1145      일반요금                  0.00                0.00
# pk_1148      일반요금                  0.00                0.00
# pk_1154      일반요금                  0.00                0.00
# pk_1157      일반요금                  0.00                0.00
# pk_1158      일반요금                  0.00                0.00
# pk_1166      일반요금                100.00                0.00
# pk_121       일반요금                 84.62               19.23
# pk_122       일반요금                100.00                0.00
# pk_123       일반요금                 85.71                0.00
# pk_129       일반요금                100.00                0.00
# pk_1350      일반요금                  0.00                0.00
# pk_138       일반요금                  0.00                0.00
# pk_139       일반요금                 66.67               16.67
# pk_140       일반요금                100.00                0.00
# pk_141       일반요금                 40.00                0.00
# pk_142       일반요금                100.00                0.00
# pk_1487      100원                 63.92               14.70
#              일반요금                 69.71               28.63
# pk_1488      100원                 73.67               15.41
#              일반요금                 78.74               27.95
# pk_1489      100원                 47.50               15.39
#              일반요금                 78.61               27.42
# pk_1494      일반요금                 83.33               20.83
# pk_1506      일반요금                 65.68                4.60
# pk_1507      일반요금                 59.22                1.94
# pk_1508      일반요금                 62.74                2.42
# pk_1509      일반요금                 57.14                0.00
# pk_1510      일반요금                100.00                0.00
# pk_187       일반요금                100.00                0.00
# pk_188       일반요금                100.00               20.00
# pk_1898      일반요금                 50.00                0.00
# pk_2005      100원                 65.31                6.12
#              일반요금                 72.31               33.85
# pk_2024      일반요금                100.00                0.00
# pk_2025      100원                 67.82               19.67
#              일반요금                 72.19               33.38
# pk_2026      100원                 74.36               16.81
#              일반요금                 74.36               35.90
# pk_2027      100원                 49.89               15.66
#              일반요금                 74.44               30.00
# pk_2028      일반요금                 83.33               16.67
# pk_2029      100원                 63.64               18.18
#              일반요금                 45.45               27.27
# pk_845       일반요금                 77.78                0.00
# pk_849       일반요금                100.00                0.00
# === 본인인증여부 × 가격구분별 재구매율/이탈방지율 (%) ===
#                                  is_repurchase  is_churn_prevented
# user_verified_label price_label
# 미인증                 일반요금                 67.65                9.63
# 인증                  100원                 62.63               15.79
#                     일반요금                 71.75               29.57
# === 가입월 × 가격구분별 재구매율/이탈방지율 (%) ===
#                      is_repurchase  is_churn_prevented
# reg_ym  price_label
# 2021-03 100원                 62.63               15.79
#         일반요금                 69.84               20.25

# %% [markdown]
# ---
# ## 8. 교호작용 gap 종합 요약 (100원 - 일반요금 차이)

# %%
interaction_vars = [
    ('gender',             '성별'),
    ('age_group',          '연령대'),
    ('payment_device',     '결제기기'),
    ('max_screen',         '동시접속수'),
    ('billing_method',     '결제방식'),
    ('reg_hour_group',     '가입시간대'),
    ('is_promotion_label', '프로모션여부'),
    ('product_code',       '상품코드'),
    ('user_verified_label','본인인증여부'),
]

for outcome in OUTCOMES:
    print(f'\n===== {OUTCOME_LABELS[outcome]} — 100원딜 효과 gap (100원 - 일반요금) =====')
    rows = []
    for col, label in interaction_vars:
        pivot = df.groupby([col, 'price_label'])[outcome].mean().mul(100).unstack('price_label')
        if '100원' in pivot.columns and '일반요금' in pivot.columns:
            pivot['gap'] = pivot['100원'] - pivot['일반요금']
            for idx, row in pivot.iterrows():
                rows.append({'변수': label, '카테고리': str(idx),
                             '100원(%)': round(row.get('100원', np.nan), 2),
                             '일반요금(%)': round(row.get('일반요금', np.nan), 2),
                             'gap(100원-일반)': round(row['gap'], 2)})
    summary = pd.DataFrame(rows).set_index(['변수', '카테고리'])
    print(summary.to_string())
# Out:
# ===== 재구매율(%) — 100원딜 효과 gap (100원 - 일반요금) =====
#                   100원(%)  일반요금(%)  gap(100원-일반)
# 변수     카테고리
# 성별     F            62.29    70.01         -7.71
#        M            63.15    73.36        -10.21
#        N           100.00    66.84         33.16
# 연령대    10대          49.36    52.27         -2.91
#        20대          55.84    67.87        -12.04
#        30대          69.76    74.79         -5.03
#        40대          67.47    68.23         -0.75
#        50대+         64.54    77.05        -12.50
# 결제기기   android      66.61    74.65         -8.04
#        ios            NaN    62.88           NaN
#        mobile       57.10    67.41        -10.31
#        ott          83.33    85.71         -2.38
#        pc           58.61    70.69        -12.09
#        smarttv      88.68    85.00          3.68
# 동시접속수  1            64.95    67.54         -2.58
#        2            73.83    74.43         -0.60
#        4            48.02    73.37        -25.35
# 결제방식   121            NaN   100.00           NaN
#        131          72.09    76.81         -4.72
#        132          62.27    73.74        -11.47
#        134          63.64    75.35        -11.70
#        140            NaN    62.88           NaN
#        151          65.25    72.68         -7.43
#        160            NaN     0.00           NaN
#        170          55.81    74.36        -18.55
#        180          56.10    67.99        -11.88
#        190          53.18    65.67        -12.49
# 가입시간대  새벽(0-5)      59.97    67.20         -7.22
#        오전(6-11)     65.58    72.09         -6.51
#        오후(12-17)    64.37    69.43         -5.06
#        저녁(18-23)    61.72    70.00         -8.29
# 프로모션여부 프로모션         62.63      NaN           NaN
#        프로모션 아님        NaN    69.84           NaN
# 상품코드   pk_1070        NaN    66.67           NaN
#        pk_1136        NaN    51.61           NaN
#        pk_1139        NaN    42.86           NaN
#        pk_1145        NaN     0.00           NaN
#        pk_1148        NaN     0.00           NaN
#        pk_1154        NaN     0.00           NaN
#        pk_1157        NaN     0.00           NaN
#        pk_1158        NaN     0.00           NaN
#        pk_1166        NaN   100.00           NaN
#        pk_121         NaN    84.62           NaN
#        pk_122         NaN   100.00           NaN
#        pk_123         NaN    85.71           NaN
#        pk_129         NaN   100.00           NaN
#        pk_1350        NaN     0.00           NaN
#        pk_138         NaN     0.00           NaN
#        pk_139         NaN    66.67           NaN
#        pk_140         NaN   100.00           NaN
#        pk_141         NaN    40.00           NaN
#        pk_142         NaN   100.00           NaN
#        pk_1487      63.92    69.71         -5.80
#        pk_1488      73.67    78.74         -5.07
#        pk_1489      47.50    78.61        -31.11
#        pk_1494        NaN    83.33           NaN
#        pk_1506        NaN    65.68           NaN
#        pk_1507        NaN    59.22           NaN
#        pk_1508        NaN    62.74           NaN
#        pk_1509        NaN    57.14           NaN
#        pk_1510        NaN   100.00           NaN
#        pk_187         NaN   100.00           NaN
#        pk_188         NaN   100.00           NaN
#        pk_1898        NaN    50.00           NaN
#        pk_2005      65.31    72.31         -7.00
#        pk_2024        NaN   100.00           NaN
#        pk_2025      67.82    72.19         -4.36
#        pk_2026      74.36    74.36          0.00
#        pk_2027      49.89    74.44        -24.56
#        pk_2028        NaN    83.33           NaN
#        pk_2029      63.64    45.45         18.18
#        pk_845         NaN    77.78           NaN
#        pk_849         NaN   100.00           NaN
# 본인인증여부 미인증            NaN    67.65           NaN
#        인증           62.63    71.75         -9.12
#
# ===== 이탈방지율(%) — 100원딜 효과 gap (100원 - 일반요금) =====
#                   100원(%)  일반요금(%)  gap(100원-일반)
# 변수     카테고리
# 성별     F            16.15    26.13         -9.98
#        M            15.23    25.66        -10.43
#        N             0.00     7.66         -7.66
# 연령대    10대          18.30    45.45        -27.16
#        20대          15.05    29.70        -14.65
#        30대          16.69    28.43        -11.74
#        40대          17.44    12.01          5.43
#        50대+         13.22    26.75        -13.52
# 결제기기   android      19.05    31.82        -12.78
#        ios            NaN     2.80           NaN
#        mobile       11.59    24.79        -13.20
#        ott           0.00    35.71        -35.71
#        pc           12.91    25.42        -12.51
#        smarttv      11.32    18.50         -7.18
# 동시접속수  1            15.94    19.25         -3.31
#        2            15.73    22.38         -6.65
#        4            15.45    21.42         -5.97
# 결제방식   121            NaN     0.00           NaN
#        131          14.16    22.73         -8.58
#        132          14.01    27.09        -13.08
#        134          16.02    30.36        -14.34
#        140            NaN     2.80           NaN
#        151          18.42    33.56        -15.15
#        160            NaN     0.00           NaN
#        170          16.28    29.49        -13.21
#        180          13.93    24.61        -10.68
#        190          14.83    35.82        -20.99
# 가입시간대  새벽(0-5)      16.59    20.06         -3.47
#        오전(6-11)     17.44    24.29         -6.85
#        오후(12-17)    15.43    18.22         -2.79
#        저녁(18-23)    15.15    18.99         -3.84
# 프로모션여부 프로모션         15.79      NaN           NaN
#        프로모션 아님        NaN    20.25           NaN
# 상품코드   pk_1070        NaN    33.33           NaN
#        pk_1136        NaN     0.00           NaN
#        pk_1139        NaN     0.00           NaN
#        pk_1145        NaN     0.00           NaN
#        pk_1148        NaN     0.00           NaN
#        pk_1154        NaN     0.00           NaN
#        pk_1157        NaN     0.00           NaN
#        pk_1158        NaN     0.00           NaN
#        pk_1166        NaN     0.00           NaN
#        pk_121         NaN    19.23           NaN
#        pk_122         NaN     0.00           NaN
#        pk_123         NaN     0.00           NaN
#        pk_129         NaN     0.00           NaN
#        pk_1350        NaN     0.00           NaN
#        pk_138         NaN     0.00           NaN
#        pk_139         NaN    16.67           NaN
#        pk_140         NaN     0.00           NaN
#        pk_141         NaN     0.00           NaN
#        pk_142         NaN     0.00           NaN
#        pk_1487      14.70    28.63        -13.93
#        pk_1488      15.41    27.95        -12.54
#        pk_1489      15.39    27.42        -12.03
#        pk_1494        NaN    20.83           NaN
#        pk_1506        NaN     4.60           NaN
#        pk_1507        NaN     1.94           NaN
#        pk_1508        NaN     2.42           NaN
#        pk_1509        NaN     0.00           NaN
#        pk_1510        NaN     0.00           NaN
#        pk_187         NaN     0.00           NaN
#        pk_188         NaN    20.00           NaN
#        pk_1898        NaN     0.00           NaN
#        pk_2005       6.12    33.85        -27.72
#        pk_2024        NaN     0.00           NaN
#        pk_2025      19.67    33.38        -13.71
#        pk_2026      16.81    35.90        -19.09
#        pk_2027      15.66    30.00        -14.34
#        pk_2028        NaN    16.67           NaN
#        pk_2029      18.18    27.27         -9.09
#        pk_845         NaN     0.00           NaN
#        pk_849         NaN     0.00           NaN
# 본인인증여부 미인증            NaN     9.63           NaN
#        인증           15.79    29.57        -13.78

# %% [markdown]
# ---
# ## 9. 교호작용 gap 시각화 (버블/스트립 차트)

# %%
for outcome in OUTCOMES:
    records = []
    for col, label in interaction_vars:
        pivot = df.groupby([col, 'price_label'])[outcome].mean().mul(100).unstack('price_label')
        if '100원' in pivot.columns and '일반요금' in pivot.columns:
            pivot['gap'] = pivot['100원'] - pivot['일반요금']
            cnt = df.groupby(col).size()
            for idx, row in pivot.iterrows():
                records.append({'변수': label, '카테고리': f'{label}:{idx}',
                                'gap': row['gap'], 'n': cnt.get(idx, 0)})
    rdf = pd.DataFrame(records).dropna(subset=['gap'])

    fig, ax = plt.subplots(figsize=(18, 6))
    scatter = ax.scatter(rdf['카테고리'], rdf['gap'],
                         s=rdf['n'] / rdf['n'].max() * 800 + 50,
                         c=rdf['gap'], cmap='RdYlGn', edgecolors='gray', linewidth=0.5, alpha=0.85)
    ax.axhline(0, color='black', linewidth=1, linestyle='--')
    plt.colorbar(scatter, ax=ax, label='gap (%)')
    ax.set_title(f'교호작용 gap 버블차트 ({OUTCOME_LABELS[outcome]})\n버블 크기 = 해당 카테고리 샘플 수')
    ax.set_xlabel('변수:카테고리')
    ax.set_ylabel('gap = 100원(%) - 일반요금(%)')
    ax.tick_params(axis='x', rotation=60)
    plt.tight_layout()
    plt.show()
